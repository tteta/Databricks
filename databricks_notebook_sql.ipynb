# %% [markdown]
# Package Imports

# %%
from databricks import sql as sql 
import pandas as pd 
import os
from sqlalchemy.orm import declarative_base, Session
from sqlalchemy import Column, String, Integer, BOOLEAN, create_engine, select

# %% [markdown]
# Configuration

# %%
# Configuration variables - from your keyvault and Databricks 
host = "adb-5941722640346466.6.azuredatabricks.net" 
http_path = "/sql/1.0/warehouses/76310ddb30acc57b" 
access_token = "dapi898a90c68187db0e64d8c396cb25d8b0-3"
catalog = ("ea_prod")
schema = ("reference_gold")

# %% [markdown]
# Functions

# %%
#this creates an engine connection to a database and runs a sql query
def run_query(database,query):
    engine = create_engine(f"databricks://token:{access_token}@{host}?http_path={http_path}&catalog={catalog}&schema={database}")
    results = engine.execute(query).fetchall()
    #print(results)
    # loop through results and print them
    data =[]
    for row in results:
        data.append(row)
    pd.DataFrame(data)
    return pd.DataFrame(data)

# %% [markdown]
# Database & SQL Statement

# %%
database = 'reference_gold'
query = 'SELECT * FROM reference_gold.account limit 5'

# %%
results = run_query(database,query)
# Out:
#    locationid                            locationname  ismainlocation  \
# 0      748061                    Royal Securities Co.               1
# 1     1232403  Standard & Poor's - Supplier Agreement               1
# 2      506129               Decade Capital Management               1
# 3      726090       MIDF Amanah Asset Management Bhd.               0
# 4     1485130            BAML Wealth Everett - WA3131               0
#
#    mainlocationid    status      substatus          city     metroarea  \
# 0          748061   Unknown        Unknown    Grandville  Grand Rapids
# 1         1232403  Prospect   Former Trial      New York       Unknown
# 2          506129  Prospect  Former Client    Boca Raton       Unknown
# 3          667090  Prospect   New Prospect  Kuala Lumpur       Unknown
# 4         1437969    Client        Unknown       Everett       Unknown
#
#   regioncode  regionname  ... localsalesrepid localsalesrepname  \
# ...

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   locationid                5 non-null      int64
#  1   locationname              5 non-null      object
#  2   ismainlocation            5 non-null      int64
#  3   mainlocationid            5 non-null      int64
#  4   status                    5 non-null      object
#  5   substatus                 5 non-null      object
#  6   city                      5 non-null      object
#  7   metroarea                 5 non-null      object
#  8   regioncode                5 non-null      object
#  9   regionname                5 non-null      object
#  10  countrycode               5 non-null      object
#  11  countryname               5 non-null      object
#  12  companysize               5 non-null      object
#  13  firmtype                  5 non-null      object
# ...
